# %%
import numpy as np
import matplotlib.pyplot as plt
from utils.signals import *

# %%
amplitude = 1
frequency = 0.5
phase = 0
duration = 5
sampling_rate = 178 / duration

# Generate a sine wave signal with noise
t, signal = generate_sin_signal(amplitude, frequency, phase, duration, sampling_rate)
plt.plot(t, signal)
plt.title("Sine wave signal with noise")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.show()

# %%
signal.shape
# Out:
# (178,)

# %%
amplitude: float = 1
frequency: float = 1
phase: float = 0
duration: float = 5
sampling_rate: float = 178 / duration
_, signal = generate_sin_signal(amplitude, frequency, phase, duration, sampling_rate, noise=True)

# %%
X = None

for i in range(20):
    t, signal = generate_sin_signal(amplitude, 0.5, i, duration, sampling_rate, noise=True)
    plt.plot(t, signal)
    plt.title("Sine wave signal with noise")
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")
    plt.show()
